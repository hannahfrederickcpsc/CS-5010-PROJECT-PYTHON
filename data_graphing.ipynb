# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# convert our csv file to a data frame
voting_data = pd.read_csv("complete_cleaned.csv")
voting_data
# Out:
#     Year  Total Registered  Percentage Change from Previous Year  \
# 0   2019         5628035.0                               -0.0100
# 1   2018         5666962.0                                0.0331
# 2   2017         5489530.0                               -0.0073
# 3   2016         5529742.0                                0.0641
# 4   2015         5196436.0                               -0.0160
# 5   2014         5281011.0                                0.0078
# 6   2013         5240286.0                               -0.0350
# 7   2012         5428833.0                                0.0610
# 8   2011         5116929.0                                0.0168
# 9   2010         5032144.0                                0.0154
# 10  2009         4955750.0                               -0.0157
# 11  2008         5034660.0                                0.1070
# 12  2007         4549864.0                               -0.0010
# ...

# %%
pres_years = voting_data.loc[voting_data['Year']%4==0]

year_total_registered = sns.scatterplot(x="Year", y="Total Registered", data=voting_data).set_title('Virginia Voters Registered Through the Years')
plt.savefig('plots/year_total_registered.pdf')
plt.show()

# %%
year_total_registered = sns.scatterplot(x="Year", y="Total Registered", data=voting_data).set_title('Virginia Voters Registered Through the Years')
year_total_registered_pres = sns.scatterplot(x="Year", y="Total Registered", data=pres_years).set_title('Virginia Voters Registered with Highlighted Presidential Years')
plt.savefig('plots/year_total_registered_pres.pdf')
plt.show()

# %%
year_total_voted = sns.scatterplot(x="Year", y="Total Voting", data=voting_data).set_title('Virginia Voters Voting Through the Years')
plt.savefig('plots/year_total_voted.pdf')
plt.show()

# %%
year_total_voted = sns.scatterplot(x="Year", y="Total Voting", data=voting_data).set_title('Virginia Voters Voting Through the Years')
year_total_voted_pres = sns.scatterplot(x="Year", y="Total Voting", data=pres_years).set_title('Virginia Voters Voting with Highlighted Presidential Years')
plt.savefig('plots/year_total_voted_pres.pdf')
plt.show()

# %%
year_total_absentee = sns.scatterplot(x="Year", y="Voting Absentee (Included in Total Voting)", data=voting_data).set_title('Virginia Voters Voting Absentee Through the Years')
plt.savefig('plots/year_total_absentee.pdf')
plt.show()

# %%
year_total_absentee = sns.scatterplot(x="Year", y="Voting Absentee (Included in Total Voting)", data=voting_data).set_title('Virginia Voters Voting Absentee Through the Years')
year_total_absentee_pres = sns.scatterplot(x="Year", y="Voting Absentee (Included in Total Voting)", data=pres_years).set_title('Virginia Voters Voting Absentee with Highlighted Presidential Years')
plt.savefig('plots/year_total_absentee_pres.pdf')
plt.show()

# %%
year_voter_turnout = sns.scatterplot(x="Year", y="Turnout (% Voting of Total Registered)", data=voting_data).set_title('Virginia Voter Turnout Through the Years')
plt.savefig('plots/year_voter_turnout.pdf')
plt.show()

# %%
year_voter_turnout = sns.scatterplot(x="Year", y="Turnout (% Voting of Total Registered)", data=voting_data).set_title('Virginia Voter Turnout Through the Years')
year_voter_turnout_pres = sns.scatterplot(x="Year", y="Turnout (% Voting of Total Registered)", data=pres_years).set_title('Virginia Voter Turnout with Highlighted Presidential Years')
plt.savefig('plots/year_voter_turnout_pres.pdf')
plt.show()

# %%
year_total_registered_party = sns.scatterplot(x="Year", y="Total Registered", hue="Party", data=voting_data).set_title('Total Registered Virginia Voters Through the Years By Winning Party')
plt.savefig('plots/year_total_registered_party.pdf')
plt.show()

# %%
post_motor_voter = voting_data.loc[voting_data['Year'] >= 1996]

year_total_registered = sns.scatterplot(x="Year", y="Total Registered", data=voting_data).set_title('Virginia Voters Registered Through the Years')
year_total_registered_post = sns.scatterplot(x="Year", y="Total Registered", data=post_motor_voter).set_title('Virginia Voters Registered with Highlighted Motor Voter Years')
plt.savefig('plots/year_total_registered_post.pdf')
plt.show()

# %%
year_total_voted = sns.scatterplot(x="Year", y="Total Voting", data=voting_data).set_title('Virginia Voters Voting Through the Years')
year_total_voted_post = sns.scatterplot(x="Year", y="Total Voting", data=post_motor_voter).set_title('Virginia Voters Voting with Highlighted Motor Voter Years')
plt.savefig('plots/year_total_voted_post.pdf')
plt.show()

# %%
year_total_absentee = sns.scatterplot(x="Year", y="Voting Absentee (Included in Total Voting)", data=voting_data).set_title('Virginia Voters Voting Absentee Through the Years')
year_total_absentee_post = sns.scatterplot(x="Year", y="Voting Absentee (Included in Total Voting)", data=post_motor_voter).set_title('Virginia Voters Voting Absentee with Highlighted Motor Voter Years')
plt.savefig('plots/year_total_absentee_post.pdf')
plt.show()

# %%
year_voter_turnout = sns.scatterplot(x="Year", y="Turnout (% Voting of Total Registered)", data=voting_data).set_title('Virginia Voter Turnout Through the Years')
year_voter_turnout_post = sns.scatterplot(x="Year", y="Turnout (% Voting of Total Registered)", data=post_motor_voter).set_title('Virginia Voter Turnout with Highlighted Motor Voter Years')
plt.savefig('plots/year_voter_turnout_post.pdf')
plt.show()
